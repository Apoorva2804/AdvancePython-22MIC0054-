# %% [markdown]
# # LAB-1

# %%
pip install bokeh
# Out:
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.0 MB 1.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.0 MB 1.3 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.3 MB/s eta 0:00:05
#    -------- ------------------------------- 1.6/7.0 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.0 MB 1.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.0 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.0 MB 1.3 MB/s eta 0:00:04
#    -------------- ------------------------- 2.6/7.0 MB 1.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.1/7.0 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/7.0 MB 1.3 MB/s eta 0:00:03
# ...

# %%
from bokeh.plotting import figure, show, output_notebook
# Enable Bokeh output inside the notebook
output_notebook()
p = figure(title="Line Chart", x_axis_label='X', y_axis_label='Y')

# line_width=2 sets the thickness of the line
p.line([1, 2, 3, 4], [4, 7, 2, 5], line_width=2)

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bccc8efb-c020-4ca3-b863-2e551d8059a0">Loading BokehJS ...</span>
#     </div>
#   <div id="a5184d2c-d3d5-4368-a06d-0b7f7bef7bad" data-root-id="p1003" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook()

p = figure(
    title="Learning Bokeh Plot",         
    x_axis_label='X Axis',               
    y_axis_label='Y Axis',              
    width=600,                          
    height=400                           
)
p.line([1, 2, 3, 4, 5], [3, 7, 8, 5, 1], line_width=2)
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b30aeee5-f66d-4144-b885-8a210f36513b">Loading BokehJS ...</span>
#     </div>
#   <div id="bda9efee-2911-4e1b-b743-3bb64df9de80" data-root-id="p1047" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Legend
output_notebook()

p = figure(
    title="Customized Bokeh Plot",
    x_axis_label="X Axis Label",
    y_axis_label="Y Axis Label",
    x_range=(0, 10),    
    y_range=(0, 20),     
    width=600,
    height=400,
    background_fill_color="#f5f5f5",  
    tools="pan,box_zoom,reset,save" 
)
line1 = p.line([1, 2, 3, 4], [4, 6, 5, 9],
               line_width=2,
               color="blue",
               legend_label="Line A")

circle1 = p.circle([1, 2, 3, 4], [4, 6, 5, 9],
                   size=8,
                   color="red",
                   alpha=0.8,
                   legend_label="Points A")

p.legend.location = "top_left"
p.legend.click_policy = "hide"  
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a126eb3f-5e0d-470e-98b4-49408b943b14">Loading BokehJS ...</span>
#     </div>
# ...
#   <div id="d05a7b6d-b4d4-4f55-a9a4-d6a2e193e4cf" data-root-id="p1091" style="display: contents;"></div>
